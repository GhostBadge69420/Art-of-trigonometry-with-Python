# %%
import sympy as sym
import numpy as np
sym.init_printing()
from IPython.display import display,Math
from sympy.abc import x,y
import math
from math import gcd
x,y = sym.symbols('x,y')
import matplotlib.pyplot as plt
import sympy.plotting.plot as symplot
x,a = sym.symbols('x,a')
from matplotlib.patches import Polygon
from matplotlib import pyplot as plt
import cmath as cm
import scipy as sp
from scipy.signal import find_peaks
import seaborn as sns

# %% [markdown]
# x = cos(Kt)cos(t)
#
# y = cos(Kt)sin(t)
#
# if k∈Z{ k is even, 2k pedals k is odd, k pedals

# %%
k = 2

t = np.linspace(0,4*np.pi,1000)

x = np.cos(k*t) * np.cos(t)
y = np.cos(k*t) * np.sin(t)

plt.plot(x,y,'m',linewidth=3)
plt.axis('square')
plt.axis('off')
plt.show()

# %%
k = 3

t = np.linspace(0,4*np.pi,1000)

x = np.cos(k*t) * np.cos(t)
y = np.cos(k*t) * np.sin(t)

plt.plot(x,y,'m',linewidth=3)
plt.axis('square')
plt.axis('off')
plt.show()

# %%
k = 4

t = np.linspace(0,4*np.pi,1000)

x = np.cos(k*t) * np.cos(t)
y = np.cos(k*t) * np.sin(t)

plt.plot(x,y,'m',linewidth=3)
plt.axis('square')
plt.axis('off')
plt.show()

# %%
k = 4.2

t = np.linspace(0,4*np.pi,1000)

x = np.cos(k*t) * np.cos(t)
y = np.cos(k*t) * np.sin(t)

plt.plot(x,y,'m',linewidth=3)
plt.axis('square')
plt.axis('off')
plt.show()

# %%
k = 4.2

t = np.linspace(0,8*np.pi,1000)

x = np.cos(k*t) * np.cos(t)
y = np.cos(k*t) * np.sin(t)

plt.plot(x,y,'m',linewidth=3)
plt.axis('square')
plt.axis('off')
plt.show()

# %% [markdown]
# # Exercise
#
# k = 0.0
#
# k = 0.5
#
# k = 1.0
#
# k = 1.5
#
# k = 2.0
#
# k = 2.5
#
# k = 3.0
#
# k = 3.5
#
# k = 4.0

# %%
fig,ax = plt.subplots(3,3,figsize=(10,6))
row, col =np.indices((3,3))

for i in range(0,9):

    k = i/2

    x = np.cos(k*t) * np.cos(t)
    y = np.cos(k*t) * np.sin(t)

    r = row.ravel()[i]
    c = col.ravel()[i]

    ax[r,c].plot(x,y,'k')
    ax[r,c].axis('square')
    ax[r,c].axis('off')
    ax[r,c].set_title('k=%s'%k)
    
plt.show()

# %%
#somme two plots missing

fig, ax = plt.subplots(4, 3, figsize=(15, 10))
row, col = np.indices((4, 3))
t = np.linspace(0, 8*np.pi, 1000)
 
for i in range(10):
    k = 3 + i / 10
    
    x = np.cos(k*t) * np.cos(t)
    y = np.cos(k*t) * np.sin(t)
    
    r = row.ravel()[i]
    c = col.ravel()[i]
 
    ax[r, c].plot(x, y, 'k')
    ax[r, c].axis('off')
    ax[r, c].axis('square')
    ax[r, c].set_title('k = %g' %k)
    
plt.savefig('Roses.png')
plt.show()
